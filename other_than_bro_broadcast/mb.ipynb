# %%
#imports
import json
import os
import warnings
from datetime import date, datetime, timedelta

import pandas as pd
import requests
from sqlalchemy import create_engine

warnings.filterwarnings("ignore")

MORNING_LEAD_LIST_ID = 214864
MORNING_BROADCAST_ID = 82319
EVENING_LEAD_LIST_ID = 214867
EVENING_BROADCAST_ID = 82321

## auth token 
# from login import auth_token

#db information
user1 = "SFPL_Connect"
password = "$%n5bF33%X"
db = "Sonata_Connect"
server = "172.17.130.216"
engine = create_engine(f"mssql+pyodbc://{user1}:{password}@{server}/{db}?driver=ODBC+Driver+17+for+SQL+Server")

def get_authorization():
    """ Get auth token """
    username = os.environ['PAYMEE_SONATA_TATA_USERNAME']
    password = os.environ['PAYMEE_SONATA_TATA_PASSWORD']
    print(username,password)
    url = "https://api-smartflo.tatateleservices.com/v1/auth/login"

    payload = {
        "email": username,
        "password": password
    }
    headers = {
        "Accept": "application/json",
        "Content-Type": "application/json"
    }

    response = requests.post(url, json=payload, headers=headers)
    if response.status_code == 200:
        return response.json()['access_token']
    else :
        return None
    
auth_token = get_authorization()
# Out:
# TACN2479 SonataFin123@@

# %%
today_date = str(date.today())
today_date = datetime.strptime(today_date, '%Y-%m-%d').strftime('%Y-%m-%d')
sql_query = f""" SET NOCOUNT ON;EXEC [{db}].[dbo].[SP_UserHierarchy_Dynamic_07Jan23] @userid = 1;SET NOCOUNT OFF """
hierarchy_df=pd.read_sql_query(sql_query,engine)

# %%
hierarchy_df.head()
# Out:
#    BUId  BUType  ReportingBUId              buname  UserID  \
# 0     1       1              0         Head Office       1
# 1   650       2              1  Prayagraj Division    7540
# 2   650       2              1  Prayagraj Division    9739
# 3   650       2              1  Prayagraj Division    9739
# 4   650       2              1  Prayagraj Division   15183
#
#              UserName  U_BUID  RoleId                RoleName
# 0       Administrator       1       1                   Admin
# 1     ANSHUMAN TIWARI     650      39  Disbursement Confirmer
# 2      LAKSHMAN SINGH     650      34           DIVISION HEAD
# 3      LAKSHMAN SINGH     650      44        Credit Committee
# 4  ABDUL KADIR ANSARI     650      58                  Audit

# %%
# hierarchy_df = hierarchy_df[hierarchy_df['RoleId']==55]
# hierarchy_df = hierarchy_df[['UserID','UserName']]
# userid_tuple = tuple(hierarchy_df['UserID'].unique().tolist())

# %%
sql_query = f""" SET NOCOUNT ON;EXEC [{db}].[dbo].[SP_UserHierarchy_Dynamic_07Jan23] @userid = 1;SET NOCOUNT OFF """
hierarchy_df=pd.read_sql_query(sql_query,engine)
hierarchy_df
# Out:
#       BUId  BUType  ReportingBUId              buname  UserID  \
# 0        1       1              0         Head Office       1
# 1      650       2              1  Prayagraj Division    7540
# 2      650       2              1  Prayagraj Division    9739
# 3      650       2              1  Prayagraj Division    9739
# 4      650       2              1  Prayagraj Division   15183
# ...    ...     ...            ...                 ...     ...
# 3004  2325       5           2104             Nirmali   25630
# 3005  2325       5           2104             Nirmali   27196
# 3006  2326       5           2206             Chandwa   27375
# 3007  2326       5           2206             Chandwa   31803
# 3008  2326       5           2206             Chandwa   31817
#
#                     UserName  U_BUID  RoleId                RoleName
# 0              Administrator       1       1                   Admin
# 1            ANSHUMAN TIWARI     650      39  Disbursement Confirmer
# 2             LAKSHMAN SINGH     650      34           DIVISION HEAD
# 3             LAKSHMAN SINGH     650      44        Credit Committee
# 4         ABDUL KADIR ANSARI     650      58                  Audit
# ...                      ...     ...     ...                     ...
# 3004         Dharmveer Kumar    2325      13          Branch Manager
# 3005  Mithilesh Kumar Paswan    2325      55                     BRO
# 3006               Rahul Raj    2326      13          Branch Manager
# 3007            SHANU  KUMAR    2326      55                     BRO
# 3008          MODASSHIR RAZA    2326      55                     BRO
#
# [3009 rows x 9 columns]

# %%
bro_df = hierarchy_df[hierarchy_df['RoleId'] == 55]
# bro_df.rename(columns={'UserName' : 'BROName'}, inplace=True)
bro_df
# Out:
#       BUId  BUType  ReportingBUId     buname  UserID                UserName  \
# 253    591       4           2179     Badaun    4829                   ANKIT
# 369      2       5            545    Sirathu    3353             RAHUL KUMAR
# 371      2       5            545    Sirathu   25715           DHEERAJ KUMAR
# 372      2       5            545    Sirathu   27274        Saurabh Kushwaha
# 373      2       5            545    Sirathu   31073           NEERAJ  KUMAR
# ...    ...     ...            ...        ...     ...                     ...
# 3002  2324       5            562  Aadhartal   31527          ANNU  KUSHWAHA
# 3003  2324       5            562  Aadhartal   31751       SAKSHI  CHOUDHARY
# 3005  2325       5           2104    Nirmali   27196  Mithilesh Kumar Paswan
# 3007  2326       5           2206    Chandwa   31803            SHANU  KUMAR
# 3008  2326       5           2206    Chandwa   31817          MODASSHIR RAZA
#
#       U_BUID  RoleId RoleName
# 253      591      55      BRO
# 369        2      55      BRO
# 371        2      55      BRO
# 372        2      55      BRO
# 373        2      55      BRO
# ...      ...     ...      ...
# 3002    2324      55      BRO
# 3003    2324      55      BRO
# 3005    2325      55      BRO
# 3007    2326      55      BRO
# 3008    2326      55      BRO
#
# [2085 rows x 9 columns]

# %%
hierarchy_df[hierarchy_df['U_BUID'] == 2179]
# Out:
#      BUId  BUType  ReportingBUId    buname  UserID            UserName  \
# 169  2179       3            654  Bareilly    7664        Vikash Singh
# 170  2179       3            654  Bareilly   18093  ASHISH KUMAR YADAV
# 171  2179       3            654  Bareilly   31467       PRANSHU SINGH
#
#      U_BUID  RoleId     RoleName
# 169    2179      35  REGION HEAD
# 170    2179      58       Audit
# 171    2179      58       Audit

# %%
bmdf = hierarchy_df[hierarchy_df['RoleId'] == 13]
# bmdf.rename(columns={'UserName' : 'BMName'}, inplace=True)
bmdf
# Out:
#       BUId  BUType  ReportingBUId     buname  UserID            UserName  \
# 183   2212       3           2200    Giridih   21376  Rajesh Kumar Yadav
# 370      2       5            545    Sirathu    4797   PINTU KUMAR YADAV
# 374      3       5           2222  Nari Bari    2426          RAJ  KAMAL
# 379      4       5            551   Akbarpur    2164         Anoop Singh
# 387      5       5            551      Tanda    3387       Krishna Kumar
# ...    ...     ...            ...        ...     ...                 ...
# 2996  2322       5            607   Nawkothi   27680        Ram Uday ray
# 2998  2323       5           2199   Dudhpura   27553    Subodh Kumar Ram
# 3001  2324       5            562  Aadhartal   26898         Ruby Dahiya
# 3004  2325       5           2104    Nirmali   25630     Dharmveer Kumar
# 3006  2326       5           2206    Chandwa   27375           Rahul Raj
#
#       U_BUID  RoleId        RoleName
# 183     2212      13  Branch Manager
# 370        2      13  Branch Manager
# 374        3      13  Branch Manager
# 379        4      13  Branch Manager
# 387        5      13  Branch Manager
# ...      ...     ...             ...
# 2996    2322      13  Branch Manager
# 2998    2323      13  Branch Manager
# 3001    2324      13  Branch Manager
# 3004    2325      13  Branch Manager
# 3006    2326      13  Branch Manager
#
# [550 rows x 9 columns]

# %%
divdf = hierarchy_df[hierarchy_df['RoleId'] == 34]
divdf
# Out:
#     BUId  BUType  ReportingBUId              buname  UserID  \
# 2    650       2              1  Prayagraj Division    9739
# 15   651       2              1    Lucknow Division    7535
# 21   652       2              1            Jabalpur   15190
# 28   653       2              1         Muzaffarpur   10849
# 36   654       2              1           Moradabad    7662
# 52  2154       2              1            Varanasi   17756
# 62  2155       2              1              Jaipur    7575
# 70  2156       2              1             Gwalior   10851
# 74  2157       2              1          Saharanpur   10846
# 81  2158       2              1               Patna   15111
# 89  2200       2              1           Ranchi DO   22544
#
#                   UserName  U_BUID  RoleId       RoleName
# 2           LAKSHMAN SINGH     650      34  DIVISION HEAD
# 15  RAKESH KUMAR CHAUDHARY     651      34  DIVISION HEAD
# 21          JITENDRA YADAV     652      34  DIVISION HEAD
# 28           KESHRAJ YADAV     653      34  DIVISION HEAD
# 36           Sandeep Singh     654      34  DIVISION HEAD
# 52              Alok Singh    2154      34  DIVISION HEAD
# 62         CHANDRA SHEKHAR    2155      34  DIVISION HEAD
# 70             Vinod singh    2156      34  DIVISION HEAD
# 74    SHASHI BHUSHAN SINGH    2157      34  DIVISION HEAD
# 81        Ajay Kumar Singh    2158      34  DIVISION HEAD
# 89        Shiv Kumar Singh    2200      34  DIVISION HEAD

# %%
regiondf = hierarchy_df[hierarchy_df['RoleId'] == 35]
regiondf
# Out:
#      BUId  BUType  ReportingBUId            buname  UserID  \
# 14    651       2              1  Lucknow Division    3557
# 20    652       2              1          Jabalpur   11856
# 42   2154       2              1          Varanasi    4366
# 49   2154       2              1          Varanasi    9741
# 64   2155       2              1            Jaipur    7665
# 93   1001       3            650         Prayagraj    7114
# 96   1002       3            651           Lucknow       0
# 99   1003       3            651            Kanpur   18043
# 102  1004       3           2157        Saharanpur   18034
# 104  1005       3            654         Moradabad    1968
# 110  1006       3            651          Faizabad   18033
# 111  1007       3            652          Jabalpur    1174
# 115  1009       3           2155         Bharatpur   15054
# 116  1010       3           2158              Gaya    4891
# 118  1011       3            654         Ghaziabad   14050
# 123  1012       3            653       Muzaffarpur   24776
# 127  1013       3           2156           Gwalior   16347
# 130  1014       3            653        Samastipur   18035
# 133  1015       3           2156             Sagar   18024
# 136  1016       3            652             Satna       0
# 138  1017       3           2157        Chandigarh    7074
# 141  1018       3           2154         Gorakhpur       0
# 143  1019       3           2154          Varanasi       0
# 145  1020       3            653          Motihari   10850
# 151  1021       3            652            Nagpur   24808
# 153  1022       3           2155            Jaipur    7342
# 155  1023       3            652         CHINDWADA   17692
# 157  1024       3            650         Sultanpur    4347
# 162  1025       3           2154       Ghazipur RO   21479
# 165  2061       3           2158             BUXAR   23657
# 166  2067       3           2158             PATNA   18036
# 167  2178       3           2157            Karnal    4708
# 169  2179       3            654          Bareilly    7664
# 172  2180       3            650         Kaushambi   18044
# 173  2182       3            652              Rewa   18023
# 177  2183       3            652             Katni    1622
# 179  2198       3            653         Darbhanga   10848
# 181  2201       3           2200     Hazaribagh RO   17841
# 184  2212       3           2200           Giridih   21376
# 186  2217       3           2200            Ranchi       0
# 188  2257       3           2255            Raipur       0
# 189  2258       3           2255       Rajnandgaon       0
# 190  2290       3           2154           Jaunpur       0
# 192  2291       3           2154            Deoria       0
# 193  2292       3            651           Sitapur       0
#
#                    UserName  U_BUID  RoleId     RoleName
# 14              Ajeet Singh     651      35  REGION HEAD
# 20       SURESH KUMAR SINGH     652      35  REGION HEAD
# 42     Ravindra Kumar Singh    2154      35  REGION HEAD
# 49    RAVINDRA PRATAP SINGH    2154      35  REGION HEAD
# 64      Krishna Vijay Singh    2155      35  REGION HEAD
# 93        Akash Jyoti singh    1001      35  REGION HEAD
# 96   REGION HEAD NOT POSTED    1002      35  REGION HEAD
# 99               SHYAMANAND    1003      35  REGION HEAD
# 102      GRIJESH  CHAUDHARY    1004      35  REGION HEAD
# 104                  sompal    1005      35  REGION HEAD
# 110         CHANDRA SHEKHAR    1006      35  REGION HEAD
# 111           shama parveen    1007      35  REGION HEAD
# 115            RAKESH SINGH    1009      35  REGION HEAD
# 116           Praveen Singh    1010      35  REGION HEAD
# 118       ASHOK KUMAR YADAV    1011      35  REGION HEAD
# 123         RAJNAND  MAURYA    1012      35  REGION HEAD
# 127     Susheel Kumar Yadav    1013      35  REGION HEAD
# 130             MANOJ KUMAR    1014      35  REGION HEAD
# 133       Shailendra Rajput    1015      35  REGION HEAD
# 136  REGION HEAD NOT POSTED    1016      35  REGION HEAD
# 138                 Sudheer    1017      35  REGION HEAD
# 141  REGION HEAD NOT POSTED    1018      35  REGION HEAD
# 143  REGION HEAD NOT POSTED    1019      35  REGION HEAD
# 145        Parasnath maorya    1020      35  REGION HEAD
# 151        BHOOPENDRA  SAHU    1021      35  REGION HEAD
# 153           Neeraj maurya    1022      35  REGION HEAD
# 155    ABHINAY KUMAR  DUBEY    1023      35  REGION HEAD
# 157            SHIV BAHADUR    1024      35  REGION HEAD
# 162             Manoj Kumar    1025      35  REGION HEAD
# 165      Suresh Kumar Saroj    2061      35  REGION HEAD
# 166         SUBHASH CHANDRA    2067      35  REGION HEAD
# 167        DIPENDRA CHAUHAN    2178      35  REGION HEAD
# 169            Vikash Singh    2179      35  REGION HEAD
# 172           KAMLESH YADAV    2180      35  REGION HEAD
# 173            Vinayak Maha    2182      35  REGION HEAD
# 177          Pradeep kachhi    2183      35  REGION HEAD
# 179     SHYAM KISHOR MISHRA    2198      35  REGION HEAD
# 181           MURARI MAURYA    2201      35  REGION HEAD
# 184      Rajesh Kumar Yadav    2212      35  REGION HEAD
# 186  REGION HEAD NOT POSTED    2217      35  REGION HEAD
# 188  REGION HEAD NOT POSTED    2257      35  REGION HEAD
# 189  REGION HEAD NOT POSTED    2258      35  REGION HEAD
# 190  REGION HEAD NOT POSTED    2290      35  REGION HEAD
# 192  REGION HEAD NOT POSTED    2291      35  REGION HEAD
# 193  REGION HEAD NOT POSTED    2292      35  REGION HEAD

# %%
hubdf = hierarchy_df[hierarchy_df['RoleId'] == 36]
hubdf
# Out:
#       BUId  BUType  ReportingBUId      buname  UserID            UserName  \
# 92    2255       2              1      Raipur   24803       Shashank Nema
# 114   1009       3           2155   Bharatpur    1074       Iqbal Siddiqi
# 117   1011       3            654   Ghaziabad    3710          ANIL KUMAR
# 137   1017       3           2157  Chandigarh    2774          LAKHVINDRA
# 185   2212       3           2200     Giridih   21376  Rajesh Kumar Yadav
# ...    ...     ...            ...         ...     ...                 ...
# 367   2307       4           1004  Kishanpura    1824   ANIL KUMAR PUNDIR
# 368   2309       4           1009      Tundla    2668       BRIJPAL SINGH
# 2246   514       5           2165      Baheri    3444         Shiv Prasad
# 2365  2057       5           2147    Miraganj    7657       Arun Kr Mahto
# 2400  2066       5           2187   Brahmapur    4459        Govind Kumar
#
#       U_BUID  RoleId  RoleName
# 92      2255      36  HUB HEAD
# 114     1009      36  HUB HEAD
# 117     1011      36  HUB HEAD
# 137     1017      36  HUB HEAD
# 185     2212      36  HUB HEAD
# ...      ...     ...       ...
# 367     2307      36  HUB HEAD
# 368     2309      36  HUB HEAD
# 2246     514      36  HUB HEAD
# 2365    2057      36  HUB HEAD
# 2400    2066      36  HUB HEAD
#
# [160 rows x 9 columns]

# %%
bro_df.columns
# Out:
# Index(['BUId', 'BUType', 'ReportingBUId', 'buname', 'UserID', 'UserName',
#        'U_BUID', 'RoleId', 'RoleName'],
#       dtype='object')

# %%
pd.merge(left=bro_df, right=bmdf, left_on='ReportingBUId', right_on='U_BUID', how='left').drop(bmdf.columns + '_y', axis=1)
# Out:
#       BUId_x  BUType_x  ReportingBUId_x   buname_x  UserID_x  \
# 0        591         4             2179     Badaun      4829
# 1          2         5              545    Sirathu      3353
# 2          2         5              545    Sirathu     25715
# 3          2         5              545    Sirathu     27274
# 4          2         5              545    Sirathu     31073
# ...      ...       ...              ...        ...       ...
# 2080    2324         5              562  Aadhartal     31527
# 2081    2324         5              562  Aadhartal     31751
# 2082    2325         5             2104    Nirmali     27196
# 2083    2326         5             2206    Chandwa     31803
# 2084    2326         5             2206    Chandwa     31817
#
#                   UserName_x  U_BUID_x  RoleId_x RoleName_x
# 0                      ANKIT       591        55        BRO
# 1                RAHUL KUMAR         2        55        BRO
# 2              DHEERAJ KUMAR         2        55        BRO
# 3           Saurabh Kushwaha         2        55        BRO
# 4              NEERAJ  KUMAR         2        55        BRO
# ...                      ...       ...       ...        ...
# 2080          ANNU  KUSHWAHA      2324        55        BRO
# 2081       SAKSHI  CHOUDHARY      2324        55        BRO
# 2082  Mithilesh Kumar Paswan      2325        55        BRO
# 2083            SHANU  KUMAR      2326        55        BRO
# 2084          MODASSHIR RAZA      2326        55        BRO
#
# [2085 rows x 9 columns]

# %%
bro_df['reporting_to_1_username'] = bro_df['ReportingBUId'].apply(lambda x : hierarchy_df[hierarchy_df['U_BUID'] == x].UserName.iloc[0])
bro_df['reporting_to_1_userid'] = bro_df['ReportingBUId'].apply(lambda x : hierarchy_df[hierarchy_df['U_BUID'] == x].UserID.iloc[0])
bro_df['reporting_to_1_roleid'] = bro_df['ReportingBUId'].apply(lambda x : hierarchy_df[hierarchy_df['U_BUID'] == x].RoleId.iloc[0])
bro_df['reporting_to_1_reportingbuid'] = bro_df['reporting_to_1_userid'].apply(lambda x : hierarchy_df[hierarchy_df['UserID'] == x].ReportingBUId.iloc[0])

# %%
bro_df ## extracted first reported to
# Out:
#       BUId  BUType  ReportingBUId     buname  UserID                UserName  \
# 253    591       4           2179     Badaun    4829                   ANKIT
# 369      2       5            545    Sirathu    3353             RAHUL KUMAR
# 371      2       5            545    Sirathu   25715           DHEERAJ KUMAR
# 372      2       5            545    Sirathu   27274        Saurabh Kushwaha
# 373      2       5            545    Sirathu   31073           NEERAJ  KUMAR
# ...    ...     ...            ...        ...     ...                     ...
# 3002  2324       5            562  Aadhartal   31527          ANNU  KUSHWAHA
# 3003  2324       5            562  Aadhartal   31751       SAKSHI  CHOUDHARY
# 3005  2325       5           2104    Nirmali   27196  Mithilesh Kumar Paswan
# 3007  2326       5           2206    Chandwa   31803            SHANU  KUMAR
# 3008  2326       5           2206    Chandwa   31817          MODASSHIR RAZA
#
#       U_BUID  RoleId RoleName reporting_to_1_username  reporting_to_1_userid  \
# 253      591      55      BRO            Vikash Singh                   7664
# 369        2      55      BRO             Shivlal pal                   1692
# 371        2      55      BRO             Shivlal pal                   1692
# 372        2      55      BRO             Shivlal pal                   1692
# 373        2      55      BRO             Shivlal pal                   1692
# ...      ...     ...      ...                     ...                    ...
# 3002    2324      55      BRO              Uma Pilley                   1175
# 3003    2324      55      BRO              Uma Pilley                   1175
# 3005    2325      55      BRO   RANDHEER KUMAR PASWAN                   3904
# 3007    2326      55      BRO            RAJESH KUMAR                   1668
# 3008    2326      55      BRO            RAJESH KUMAR                   1668
#
#       reporting_to_1_roleid  reporting_to_1_reportingbuid
# 253                      35                           654
# 369                      36                          2180
# 371                      36                          2180
# 372                      36                          2180
# 373                      36                          2180
# ...                     ...                           ...
# 3002                     36                          1007
# 3003                     36                          1007
# 3005                     36                          2198
# 3007                     36                          2201
# 3008                     36                          2201
#
# [2085 rows x 13 columns]

# %%
## extracting second reported to
# bro_df['reporting_to_2_username'] = bro_df['ReportingBUId'].apply(lambda x : hierarchy_df[hierarchy_df['U_BUID'] == x].UserName.iloc[0])
# bro_df['reporting_to_1_userid'] = bro_df['ReportingBUId'].apply(lambda x : hierarchy_df[hierarchy_df['U_BUID'] == x].UserID.iloc[0]) 
# bro_df['reporting_to_1_roleid'] = bro_df['ReportingBUId'].apply(lambda x : hierarchy_df[hierarchy_df['U_BUID'] == x].RoleId.iloc[0])

# %%
bro_df.columns
# Out:
# Index(['BUId', 'BUType', 'ReportingBUId', 'buname', 'UserID', 'UserName',
#        'U_BUID', 'RoleId', 'RoleName', 'reporting_to_1_username',
#        'reporting_to_1_userid', 'reporting_to_1_roleid',
#        'reporting_to_1_reportingbuid'],
#       dtype='object')

# %%
# bro_df.drop(columns=['reporting_to_2_username'], inplace=True)

# %%
## level 2
bro_df['reporting_to_2_username'] = bro_df['reporting_to_1_reportingbuid'].apply(lambda x : hierarchy_df[hierarchy_df['U_BUID'] == x].UserName.iloc[0])
bro_df['reporting_to_2_userid'] = bro_df['reporting_to_1_reportingbuid'].apply(lambda x : hierarchy_df[hierarchy_df['U_BUID'] == x].UserID.iloc[0])
bro_df['reporting_to_2_roleid'] = bro_df['reporting_to_1_reportingbuid'].apply(lambda x : hierarchy_df[hierarchy_df['U_BUID'] == x].RoleId.iloc[0])
bro_df['reporting_to_2_reportingbuid'] = bro_df['reporting_to_2_userid'].apply(lambda x : hierarchy_df[hierarchy_df['UserID'] == x].ReportingBUId.iloc[0])

# %%
bro_df
# Out:
#       BUId  BUType  ReportingBUId     buname  UserID                UserName  \
# 253    591       4           2179     Badaun    4829                   ANKIT
# 369      2       5            545    Sirathu    3353             RAHUL KUMAR
# 371      2       5            545    Sirathu   25715           DHEERAJ KUMAR
# 372      2       5            545    Sirathu   27274        Saurabh Kushwaha
# 373      2       5            545    Sirathu   31073           NEERAJ  KUMAR
# ...    ...     ...            ...        ...     ...                     ...
# 3002  2324       5            562  Aadhartal   31527          ANNU  KUSHWAHA
# 3003  2324       5            562  Aadhartal   31751       SAKSHI  CHOUDHARY
# 3005  2325       5           2104    Nirmali   27196  Mithilesh Kumar Paswan
# 3007  2326       5           2206    Chandwa   31803            SHANU  KUMAR
# 3008  2326       5           2206    Chandwa   31817          MODASSHIR RAZA
#
#       U_BUID  RoleId RoleName reporting_to_1_username  reporting_to_1_userid  \
# 253      591      55      BRO            Vikash Singh                   7664
# 369        2      55      BRO             Shivlal pal                   1692
# 371        2      55      BRO             Shivlal pal                   1692
# 372        2      55      BRO             Shivlal pal                   1692
# 373        2      55      BRO             Shivlal pal                   1692
# ...      ...     ...      ...                     ...                    ...
# 3002    2324      55      BRO              Uma Pilley                   1175
# 3003    2324      55      BRO              Uma Pilley                   1175
# 3005    2325      55      BRO   RANDHEER KUMAR PASWAN                   3904
# 3007    2326      55      BRO            RAJESH KUMAR                   1668
# 3008    2326      55      BRO            RAJESH KUMAR                   1668
#
#       reporting_to_1_roleid  reporting_to_1_reportingbuid  \
# 253                      35                           654
# 369                      36                          2180
# 371                      36                          2180
# 372                      36                          2180
# 373                      36                          2180
# ...                     ...                           ...
# 3002                     36                          1007
# 3003                     36                          1007
# 3005                     36                          2198
# 3007                     36                          2201
# 3008                     36                          2201
#
#      reporting_to_2_username  reporting_to_2_userid  reporting_to_2_roleid  \
# 253            Sandeep Singh                   7662                     34
# 369            KAMLESH YADAV                  18044                     35
# 371            KAMLESH YADAV                  18044                     35
# 372            KAMLESH YADAV                  18044                     35
# 373            KAMLESH YADAV                  18044                     35
# ...                      ...                    ...                    ...
# 3002           shama parveen                   1174                     35
# 3003           shama parveen                   1174                     35
# 3005     SHYAM KISHOR MISHRA                  10848                     35
# 3007           MURARI MAURYA                  17841                     35
# 3008           MURARI MAURYA                  17841                     35
#
#       reporting_to_2_reportingbuid
# 253                              1
# 369                            650
# 371                            650
# 372                            650
# 373                            650
# ...                            ...
# 3002                           652
# 3003                           652
# 3005                           653
# 3007                          2200
# 3008                          2200
#
# [2085 rows x 17 columns]

# %%
sql_query = f"""SET NOCOUNT ON;EXEC [{db}].[dbo].[SP_UserHierarchy_Dynamic_07Jan23] @userid = 1;SET NOCOUNT OFF"""
df=pd.read_sql_query(sql_query,engine)
df = df.replace(['Prayagraj Division','Lucknow Division'],['Prayagraj', 'Lucknow'])

# %%
df = df.replace(['Prayagraj Division','Lucknow Division'],['Prayagraj', 'Lucknow'])
#WE CREATE A NEW USER HIERARCHY TABLE
div_df = df[(df['RoleId']==34)&(df['RoleName']=='DIVISION HEAD')][['U_BUID','UserID','UserName','buname']]
print(len(div_df))
div_df.rename(columns={'U_BUID':'Div_BUID','buname':'DivName','UserID':'Div_UserID','UserName':'Div_UserName'}, inplace=True)
reg_df = df[(df['RoleId']==35)&(df['RoleName']=='REGION HEAD')][['U_BUID','UserID','UserName','buname','ReportingBUId']]
print(len(reg_df))
reg_df.rename(columns={'U_BUID':'Region_BUID','ReportingBUId':'Region_ReportingBUId','buname':'RegionName','UserID':'Region_UserID','UserName':'Region_UserName'}, inplace=True)
# hub_df = df[(df['RoleId']==44)&(df['RoleName']=='Credit Committee')][['U_BUID','UserID','UserName','buname','ReportingBUId']]
hub_df = df[(df['RoleId'].isin([36,44,42]))&(df['RoleName'].isin(['Credit Committee','Credit Officer','HUB HEAD']))][['U_BUID','UserID','UserName','buname','ReportingBUId','RoleId']]
#We will classify HUB,CRC,CRO on the basis of RID
hub_df.rename(columns={'U_BUID':'Hub_BUID','ReportingBUId':'Hub_ReportingBUId','buname':'HubName','UserID':'Hub_UserID','UserName':'Hub_UserName','RoleId':'RID'}, inplace=True)
bm_df = df[(df['RoleId']==13)&(df['RoleName']=='Branch Manager')][['U_BUID','buname','UserID','UserName','ReportingBUId']]
bm_df.rename(columns={'U_BUID':'BM_BUID','ReportingBUId':'BM_ReportingBUId','buname':'BranchName','UserID':'BM_UserID','UserName':'BM_UserName'}, inplace=True)
bro_df = df[(df['RoleId']==55)&(df['RoleName']=='BRO')][['U_BUID','UserID','UserName','buname']]
bro_df.rename(columns={'U_BUID':'BRO_BUID','UserID':'BRO_UserID','UserName':'BRO_UserName','buname':'BRO_buname'}, inplace=True)
M1 = pd.merge(bro_df,bm_df,left_on='BRO_BUID',right_on='BM_BUID',how='left').drop_duplicates(subset='BRO_UserID')
M2 = pd.merge(M1,hub_df,left_on='BM_ReportingBUId',right_on='Hub_BUID',how='left').drop_duplicates(subset='BRO_UserID')
M3 = pd.merge(M2,reg_df,left_on='Hub_ReportingBUId',right_on='Region_BUID',how='left').drop_duplicates(subset='BRO_UserID')
dF = pd.merge(M3,div_df,left_on='Region_ReportingBUId',right_on='Div_BUID',how='left').drop_duplicates(subset='BRO_UserID')
    # dF.to_csv('userhierdupe.csv')
# Out:
# 11
# 45

# %%
df = df.replace(['Prayagraj Division','Lucknow Division'],['Prayagraj', 'Lucknow'])
#WE CREATE A NEW USER HIERARCHY TABLE
div_df = df[(df['RoleId']==34)&(df['RoleName']=='DIVISION HEAD')][['U_BUID','UserID','UserName','buname']]
div_df.rename(columns={'U_BUID':'Div_BUID','buname':'DivName','UserID':'Div_UserID','UserName':'Div_UserName'}, inplace=True)
reg_df = df[(df['RoleId']==35)&(df['RoleName']=='REGION HEAD')][['U_BUID','UserID','UserName','buname','ReportingBUId']]
reg_df.rename(columns={'U_BUID':'Region_BUID','ReportingBUId':'Region_ReportingBUId','buname':'RegionName','UserID':'Region_UserID','UserName':'Region_UserName'}, inplace=True)
# hub_df = df[(df['RoleId']==44)&(df['RoleName']=='Credit Committee')][['U_BUID','UserID','UserName','buname','ReportingBUId']]
hub_df = df[(df['RoleId'].isin([36,44,42]))&(df['RoleName'].isin(['Credit Committee','Credit Officer','HUB HEAD']))][['U_BUID','UserID','UserName','buname','ReportingBUId','RoleId']]
#We will classify HUB,CRC,CRO on the basis of RID
hub_df.rename(columns={'U_BUID':'Hub_BUID','ReportingBUId':'Hub_ReportingBUId','buname':'HubName','UserID':'Hub_UserID','UserName':'Hub_UserName','RoleId':'RID'}, inplace=True)
bm_df = df[(df['RoleId']==13)&(df['RoleName']=='Branch Manager')][['U_BUID','buname','UserID','UserName','ReportingBUId']]
bm_df.rename(columns={'U_BUID':'BM_BUID','ReportingBUId':'BM_ReportingBUId','buname':'BranchName','UserID':'BM_UserID','UserName':'BM_UserName'}, inplace=True)
bro_df = df[(df['RoleId']==55)&(df['RoleName']=='BRO')][['U_BUID','UserID','UserName','buname']]
bro_df.rename(columns={'U_BUID':'BRO_BUID','UserID':'BRO_UserID','UserName':'BRO_UserName','buname':'BRO_buname'}, inplace=True)
M1 = pd.merge(bro_df,bm_df,left_on='BRO_BUID',right_on='BM_BUID',how='left').drop_duplicates(subset='BRO_UserID')
M2 = pd.merge(M1,hub_df,left_on='BM_ReportingBUId',right_on='Hub_BUID',how='left').drop_duplicates(subset='BRO_UserID')
M3 = pd.merge(M2,reg_df,left_on='Hub_ReportingBUId',right_on='Region_BUID',how='left').drop_duplicates(subset='BRO_UserID')
dF = pd.merge(M3,div_df,left_on='Region_ReportingBUId',right_on='Div_BUID',how='left').drop_duplicates(subset='BRO_UserID')
# dF.to_csv('userhierdupe.csv')

# %%
cols_to_fill = ['BM_BUID','BM_UserID','BM_ReportingBUId','Hub_BUID','Hub_UserID','Hub_ReportingBUId','RID', 'Region_BUID','Region_UserID','Region_ReportingBUId','Div_BUID','Div_UserID']

# %%
dF[cols_to_fill] = dF[cols_to_fill].fillna(0).astype('int', errors='ignore')

# %%
dF
# Out:
#       BRO_BUID  BRO_UserID            BRO_UserName BRO_buname  BM_BUID  \
# 0          591        4829                   ANKIT     Badaun        0
# 1            2        3353             RAHUL KUMAR    Sirathu        2
# 2            2       25715           DHEERAJ KUMAR    Sirathu        2
# 3            2       27274        Saurabh Kushwaha    Sirathu        2
# 4            2       31073           NEERAJ  KUMAR    Sirathu        2
# ...        ...         ...                     ...        ...      ...
# 2080      2324       31527          ANNU  KUSHWAHA  Aadhartal     2324
# 2081      2324       31751       SAKSHI  CHOUDHARY  Aadhartal     2324
# 2082      2325       27196  Mithilesh Kumar Paswan    Nirmali     2325
# 2083      2326       31803            SHANU  KUMAR    Chandwa     2326
# 2084      2326       31817          MODASSHIR RAZA    Chandwa     2326
#
#      BranchName  BM_UserID        BM_UserName  BM_ReportingBUId  Hub_BUID  \
# 0           NaN          0                NaN                 0         0
# 1       Sirathu       4797  PINTU KUMAR YADAV               545       545
# 2       Sirathu       4797  PINTU KUMAR YADAV               545       545
# 3       Sirathu       4797  PINTU KUMAR YADAV               545       545
# 4       Sirathu       4797  PINTU KUMAR YADAV               545       545
# ...         ...        ...                ...               ...       ...
# 2080  Aadhartal      26898        Ruby Dahiya               562       562
# 2081  Aadhartal      26898        Ruby Dahiya               562       562
# 2082    Nirmali      25630    Dharmveer Kumar              2104      2104
# 2083    Chandwa      27375          Rahul Raj              2206      2206
# 2084    Chandwa      27375          Rahul Raj              2206      2206
#
#       Hub_UserID           Hub_UserName         HubName  Hub_ReportingBUId  \
# 0              0                    NaN             NaN                  0
# 1           1692            Shivlal pal        BHARWARI               2180
# 2           1692            Shivlal pal        BHARWARI               2180
# 3           1692            Shivlal pal        BHARWARI               2180
# 4           1692            Shivlal pal        BHARWARI               2180
# ...          ...                    ...             ...                ...
# 2080        1175             Uma Pilley  JABALPUR URBAN               1007
# 2081        1175             Uma Pilley  JABALPUR URBAN               1007
# 2082        3904  RANDHEER KUMAR PASWAN       Madhubani               2198
# 2083        1668           RAJESH KUMAR          Chatra               2201
# 2084        1668           RAJESH KUMAR          Chatra               2201
#
#       RID  Region_BUID  Region_UserID      Region_UserName     RegionName  \
# 0       0            0              0                  NaN            NaN
# 1      36         2180          18044        KAMLESH YADAV      Kaushambi
# 2      36         2180          18044        KAMLESH YADAV      Kaushambi
# 3      36         2180          18044        KAMLESH YADAV      Kaushambi
# 4      36         2180          18044        KAMLESH YADAV      Kaushambi
# ...   ...          ...            ...                  ...            ...
# 2080   36         1007           1174        shama parveen       Jabalpur
# 2081   36         1007           1174        shama parveen       Jabalpur
# 2082   36         2198          10848  SHYAM KISHOR MISHRA      Darbhanga
# 2083   36         2201          17841        MURARI MAURYA  Hazaribagh RO
# 2084   36         2201          17841        MURARI MAURYA  Hazaribagh RO
#
#       Region_ReportingBUId  Div_BUID  Div_UserID      Div_UserName  \
# 0                        0         0           0               NaN
# 1                      650       650        9739    LAKSHMAN SINGH
# 2                      650       650        9739    LAKSHMAN SINGH
# 3                      650       650        9739    LAKSHMAN SINGH
# 4                      650       650        9739    LAKSHMAN SINGH
# ...                    ...       ...         ...               ...
# 2080                   652       652       15190    JITENDRA YADAV
# 2081                   652       652       15190    JITENDRA YADAV
# 2082                   653       653       10849     KESHRAJ YADAV
# 2083                  2200      2200       22544  Shiv Kumar Singh
# 2084                  2200      2200       22544  Shiv Kumar Singh
#
#           DivName
# 0             NaN
# 1       Prayagraj
# 2       Prayagraj
# 3       Prayagraj
# 4       Prayagraj
# ...           ...
# 2080     Jabalpur
# 2081     Jabalpur
# 2082  Muzaffarpur
# 2083    Ranchi DO
# 2084    Ranchi DO
#
# [2085 rows x 24 columns]

# %%
dF.RID.unique()
# Out:
# array([ 0, 36, 44])

# %%
dF.head()
# Out:
#    BRO_BUID  BRO_UserID      BRO_UserName BRO_buname  BM_BUID BranchName  \
# 0       591        4829             ANKIT     Badaun        0        NaN
# 1         2        3353       RAHUL KUMAR    Sirathu        2    Sirathu
# 2         2       25715     DHEERAJ KUMAR    Sirathu        2    Sirathu
# 3         2       27274  Saurabh Kushwaha    Sirathu        2    Sirathu
# 4         2       31073     NEERAJ  KUMAR    Sirathu        2    Sirathu
#
#    BM_UserID        BM_UserName  BM_ReportingBUId  Hub_BUID  Hub_UserID  \
# 0          0                NaN                 0         0           0
# 1       4797  PINTU KUMAR YADAV               545       545        1692
# 2       4797  PINTU KUMAR YADAV               545       545        1692
# 3       4797  PINTU KUMAR YADAV               545       545        1692
# 4       4797  PINTU KUMAR YADAV               545       545        1692
#
#   Hub_UserName   HubName  Hub_ReportingBUId  RID  Region_BUID  Region_UserID  \
# 0          NaN       NaN                  0    0            0              0
# 1  Shivlal pal  BHARWARI               2180   36         2180          18044
# 2  Shivlal pal  BHARWARI               2180   36         2180          18044
# 3  Shivlal pal  BHARWARI               2180   36         2180          18044
# 4  Shivlal pal  BHARWARI               2180   36         2180          18044
#
#   Region_UserName RegionName  Region_ReportingBUId  Div_BUID  Div_UserID  \
# 0             NaN        NaN                     0         0           0
# 1   KAMLESH YADAV  Kaushambi                   650       650        9739
# 2   KAMLESH YADAV  Kaushambi                   650       650        9739
# 3   KAMLESH YADAV  Kaushambi                   650       650        9739
# 4   KAMLESH YADAV  Kaushambi                   650       650        9739
#
#      Div_UserName    DivName
# 0             NaN        NaN
# 1  LAKSHMAN SINGH  Prayagraj
# 2  LAKSHMAN SINGH  Prayagraj
# 3  LAKSHMAN SINGH  Prayagraj
# 4  LAKSHMAN SINGH  Prayagraj

# %%
today_date = datetime.strptime(str(date.today()), '%Y-%m-%d').strftime('%Y-%m-%d')
sql_query = f""" SET NOCOUNT ON;EXEC [{db}].[dbo].[SP_UserHierarchy_Dynamic_07Jan23] @userid = 1;SET NOCOUNT OFF """
hierarchy_df=pd.read_sql_query(sql_query,engine)
hierarchy_df = hierarchy_df[hierarchy_df['RoleId']==55]
hierarchy_df = hierarchy_df[['UserID','UserName']]
userid_tuple = tuple(hierarchy_df['UserID'].unique().tolist())
sql_query = f""" SELECT CallingNumber,UserID FROM Sonata_Connect.dbo.accounts_calling_number_list
    WHERE UserID in {userid_tuple} """
contact_df = pd.read_sql_query(sql_query,engine)
main_df = pd.merge(hierarchy_df,contact_df,on='UserID',how='right')
# sql_query = f""" SELECT TOP 10 assigned_to,status,deadline_date FROM Sonata_Connect.dbo.accounts_task_details
#     WHERE assigned_to in {userid_tuple} and deadline_date = {today_date} """
sql_query = f""" SELECT assigned_to,status,deadline_date,category FROM Sonata_Connect.dbo.accounts_task_details
    WHERE deadline_date = '{today_date}' and category in ('3','5','7','10')"""

task_df = pd.read_sql_query(sql_query,engine)
task_df = task_df[(task_df['status'] == 'Pending')|(task_df['status'] == 'Re-Schedule')]
pending_task_df = task_df.groupby('assigned_to')['deadline_date'].count().reset_index()
pending_task_df = pending_task_df.rename(columns={'deadline_date':'Pending_Count'})

print("Length of pending taks : ", len(pending_task_df))

collection_task_df = task_df[task_df['category']=='3']
collection_task_df = collection_task_df.groupby('assigned_to')['deadline_date'].count().reset_index()
collection_task_df = collection_task_df.rename(columns={'deadline_date':'collection_count'})

proposal_task_df = task_df[task_df['category']=='5']
proposal_task_df = proposal_task_df.groupby('assigned_to')['deadline_date'].count().reset_index()
proposal_task_df = proposal_task_df.rename(columns={'deadline_date':'proposal_count'})

retention_task_df = task_df[task_df['category']=='7']
retention_task_df = retention_task_df.groupby('assigned_to')['deadline_date'].count().reset_index()
retention_task_df = retention_task_df.rename(columns={'deadline_date':'retention_count'})

wrong_number_task_df = task_df[task_df['category']=='10']
wrong_number_task_df = wrong_number_task_df.groupby('assigned_to')['deadline_date'].count().reset_index()
wrong_number_task_df = wrong_number_task_df.rename(columns={'deadline_date':'wrong_number_count'})

task_df = task_df[(task_df['status'] == 'Completed')]
completed_task_df = task_df.groupby('assigned_to')['deadline_date'].count().reset_index()
completed_task_df = completed_task_df.rename(columns={'deadline_date':'Completed_Count'})

main_df = pd.merge(main_df,pending_task_df,left_on='UserID',right_on='assigned_to',how='right')
main_df = pd.merge(main_df,collection_task_df,left_on='UserID',right_on='assigned_to',how='left')
main_df = pd.merge(main_df,proposal_task_df,left_on='UserID',right_on='assigned_to',how='left')
main_df = pd.merge(main_df,retention_task_df,left_on='UserID',right_on='assigned_to',how='left')
main_df = pd.merge(main_df,wrong_number_task_df,left_on='UserID',right_on='assigned_to',how='left')


main_df = main_df.drop(columns=['assigned_to_y', 'assigned_to_x'], axis=1).dropna(subset=['UserID']).fillna(0).reset_index(drop=True)

main_df['collection_count'] = main_df['collection_count'].astype(int, errors='ignore')
main_df['proposal_count'] = main_df['proposal_count'].astype(int, errors='ignore')
main_df['retention_count'] = main_df['retention_count'].astype(int, errors='ignore')
main_df['wrong_number_count'] = main_df['wrong_number_count'].astype(int, errors='ignore')

main_df['UserID'] = main_df['UserID'].astype(int, errors='ignore')
main_df['UserName'] = main_df['UserName'].apply(lambda x : x.title())


main_df.head()
# Out:
# Length of pending taks :  522
#    UserID       UserName CallingNumber  Pending_Count  collection_count  \
# 0    1478       Ram Roop    9076605730              1                 0
# 1    1709          Ballu    8960154523              2                 0
# 2    2107  Chiraunji Lal    7318080248              1                 0
# 3    2916   Vijay  Kumar    7080200377              1                 0
# 4    3004      Ram Jivan    7897996910             19                19
#
#    proposal_count  retention_count  assigned_to  wrong_number_count
# 0               0                1          0.0                   0
# 1               0                2          0.0                   0
# 2               0                1          0.0                   0
# 3               0                1          0.0                   0
# 4               0                0          0.0                   0

# %%
len(main_df)
# Out:
# 467

# %%
today_df = pd.merge(left=main_df, right=dF, left_on='UserID', right_on='BRO_UserID', how='left')

# %%
today_df
# Out:
#      UserID         UserName CallingNumber  Pending_Count  collection_count  \
# 0      1478         Ram Roop    9076605730              1                 0
# 1      1709            Ballu    8960154523              2                 0
# 2      2107    Chiraunji Lal    7318080248              1                 0
# 3      2916     Vijay  Kumar    7080200377              1                 0
# 4      3004        Ram Jivan    7897996910             19                19
# ..      ...              ...           ...            ...               ...
# 462   31779     Prity Kumari    9142222360              3                 3
# 463   31810     Pankaj Kumar    9065230039              1                 1
# 464   31827     Sumit  Kumar    8192892088              6                 6
# 465   31836    Mukesh  Verma    6261403746              2                 2
# 466   31907  Akhilesh  Kumar    8292195969              1                 1
#
#      proposal_count  retention_count  assigned_to  wrong_number_count  \
# 0                 0                1          0.0                   0
# 1                 0                2          0.0                   0
# 2                 0                1          0.0                   0
# 3                 0                1          0.0                   0
# 4                 0                0          0.0                   0
# ..              ...              ...          ...                 ...
# 462               0                0          0.0                   0
# 463               0                0          0.0                   0
# 464               0                0          0.0                   0
# 465               0                0          0.0                   0
# 466               0                0          0.0                   0
#
#      BRO_BUID  BRO_UserID     BRO_UserName       BRO_buname  BM_BUID  \
# 0           5        1478         Ram Roop            Tanda        5
# 1          92        1709            BALLU           Handia       92
# 2          80        2107    CHIRAUNJI LAL          Mauaima       80
# 3          20        2916     VIJAY  KUMAR            Derwa       20
# 4         269        3004        RAM JIVAN  Lakhimpur Khiri      269
# ..        ...         ...              ...              ...      ...
# 462       404       31779     PRITY KUMARI            Maker      404
# 463       357       31810     PANKAJ KUMAR         Mashrakh      357
# 464       200       31827     SUMIT  KUMAR        Vilashpur      200
# 465      2096       31836    MUKESH  VERMA    Rampur naikin     2096
# 466       511       31907  AKHILESH  KUMAR       Chanpattia      511
#
#           BranchName  BM_UserID            BM_UserName  BM_ReportingBUId  \
# 0              Tanda       3387          Krishna Kumar               551
# 1             Handia       2896           KARUNA SAGAR              2132
# 2            Mauaima       7365          Anurag Mishra               549
# 3              Derwa      15083               NAND LAL               550
# 4    Lakhimpur Khiri       3949     SURAJ KUMAR MAURYA              2220
# ..               ...        ...                    ...               ...
# 462            Maker      25041           Sujeet Kumar              2131
# 463         Mashrakh       4964            SUMIT KUMAR               605
# 464        Vilashpur      16428                BRIJPAL               599
# 465    Rampur naikin       7328  Arvind Kumar Kushvaha              2094
# 466       Chanpattia       5055            SANOJ KUMAR              2273
#
#      Hub_BUID  Hub_UserID             Hub_UserName       HubName  \
# 0         551        7660  Dharmendra Pratap Singh      AKBARPUR
# 1        2132        3883           RAVINDRA KUMAR        HANDIA
# 2         549        1466      Vikash Kumar Maurya      PHOOLPUR
# 3         550       24795       Saurabh Srivastava    PRATAPGARH
# 4        2220        3681            AVADESH KUMAR     Lakhimpur
# ..        ...         ...                      ...           ...
# 462      2131        1543                 DINDAYAL       MOTIPUR
# 463       605        3852             NANDLAL  RAM       Chapra
# 464       599       17668            Mohit Chauhan         Ladwa
# 465      2094       18027    PRABHAT SINGH CHOUHAN         Sidhi
# 466      2273       24860            Santosh Kumar  Narkatiaganj
#
#      Hub_ReportingBUId  RID  Region_BUID  Region_UserID  \
# 0                 1024   36         1024           4347
# 1                 1001   36         1001           7114
# 2                 1001   36         1001           7114
# 3                 1001   36         1001           7114
# 4                 2292   36         2292              0
# ..                 ...  ...          ...            ...
# 462               1012   36         1012          24776
# 463               1012   36         1012          24776
# 464               2178   36         2178           4708
# 465               2182   36         2182          18023
# 466               1020   36         1020          10850
#
#             Region_UserName   RegionName  Region_ReportingBUId  Div_BUID  \
# 0              SHIV BAHADUR    Sultanpur                   650       650
# 1         Akash Jyoti singh    Prayagraj                   650       650
# 2         Akash Jyoti singh    Prayagraj                   650       650
# 3         Akash Jyoti singh    Prayagraj                   650       650
# 4    REGION HEAD NOT POSTED      Sitapur                   651       651
# ..                      ...          ...                   ...       ...
# 462         RAJNAND  MAURYA  Muzaffarpur                   653       653
# 463         RAJNAND  MAURYA  Muzaffarpur                   653       653
# 464        DIPENDRA CHAUHAN       Karnal                  2157      2157
# 465            Vinayak Maha         Rewa                   652       652
# 466        Parasnath maorya     Motihari                   653       653
#
#      Div_UserID            Div_UserName      DivName
# 0          9739          LAKSHMAN SINGH    Prayagraj
# 1          9739          LAKSHMAN SINGH    Prayagraj
# 2          9739          LAKSHMAN SINGH    Prayagraj
# 3          9739          LAKSHMAN SINGH    Prayagraj
# 4          7535  RAKESH KUMAR CHAUDHARY      Lucknow
# ..          ...                     ...          ...
# 462       10849           KESHRAJ YADAV  Muzaffarpur
# 463       10849           KESHRAJ YADAV  Muzaffarpur
# 464       10846    SHASHI BHUSHAN SINGH   Saharanpur
# 465       15190          JITENDRA YADAV     Jabalpur
# 466       10849           KESHRAJ YADAV  Muzaffarpur
#
# [467 rows x 33 columns]

# %%
today_df.columns
# Out:
# Index(['UserID', 'UserName', 'CallingNumber', 'Pending_Count',
#        'collection_count', 'proposal_count', 'retention_count', 'assigned_to',
#        'wrong_number_count', 'BRO_BUID', 'BRO_UserID', 'BRO_UserName',
#        'BRO_buname', 'BM_BUID', 'BranchName', 'BM_UserID', 'BM_UserName',
#        'BM_ReportingBUId', 'Hub_BUID', 'Hub_UserID', 'Hub_UserName', 'HubName',
#        'Hub_ReportingBUId', 'RID', 'Region_BUID', 'Region_UserID',
#        'Region_UserName', 'RegionName', 'Region_ReportingBUId', 'Div_BUID',
#        'Div_UserID', 'Div_UserName', 'DivName'],
#       dtype='object')

# %%
cols_to_sum = ['Pending_Count','collection_count', 'proposal_count', 'retention_count', 'wrong_number_count']

# %%
for col in cols_to_sum:
    print(today_df[col].sum())
# Out:
# 1035
# 799
# 0
# 153
# 83

# %%
len(bm_df)
# Out:
# 529

# %%
main_df.columns
# Out:
# Index(['UserID', 'UserName', 'CallingNumber', 'Pending_Count',
#        'collection_count', 'proposal_count', 'retention_count', 'assigned_to',
#        'wrong_number_count'],
#       dtype='object')

# %%
dF.columns
# Out:
# Index(['BRO_BUID', 'BRO_UserID', 'BRO_UserName', 'BRO_buname', 'BM_BUID',
#        'BranchName', 'BM_UserID', 'BM_UserName', 'BM_ReportingBUId',
#        'Hub_BUID', 'Hub_UserID', 'Hub_UserName', 'HubName',
#        'Hub_ReportingBUId', 'RID', 'Region_BUID', 'Region_UserID',
#        'Region_UserName', 'RegionName', 'Region_ReportingBUId', 'Div_BUID',
#        'Div_UserID', 'Div_UserName', 'DivName'],
#       dtype='object')

# %%
## tasks for bmdf
bm_df_tasks = pd.merge(left=main_df, right=bm_df, left_on='UserID', right_on='BM_UserID', how='left')[['UserID'	,'UserName'	,'CallingNumber'] + cols_to_sum]

# %%
div_df.columns
# Out:
# Index(['Div_BUID', 'Div_UserID', 'Div_UserName', 'DivName'], dtype='object')

# %%
## tasks for hubdf
hubdf_tasks = pd.merge(left=main_df, right=hub_df, left_on='UserID', right_on='Hub_UserID', how='left')[['UserID'	,'UserName'	,'CallingNumber'] + cols_to_sum]

# %%
## tasks for regdf
regdf_tasks = pd.merge(left=main_df, right=reg_df, left_on='UserID', right_on='Region_UserID', how='left')[['UserID'	,'UserName'	,'CallingNumber'] + cols_to_sum]

# %%
## tasks for divdf
divdf_tasks = pd.merge(left=main_df, right=div_df, left_on='UserID', right_on='Div_UserID', how='left')[['UserID'	,'UserName'	,'CallingNumber'] + cols_to_sum]

# %%
divdf_tasks['Pending_Count'].sum()
# Out:
# 1035

# %%
today_df.columns
# Out:
# Index(['UserID', 'UserName', 'CallingNumber', 'Pending_Count',
#        'collection_count', 'proposal_count', 'retention_count', 'assigned_to',
#        'wrong_number_count', 'BRO_BUID', 'BRO_UserID', 'BRO_UserName',
#        'BRO_buname', 'BM_BUID', 'BranchName', 'BM_UserID', 'BM_UserName',
#        'BM_ReportingBUId', 'Hub_BUID', 'Hub_UserID', 'Hub_UserName', 'HubName',
#        'Hub_ReportingBUId', 'RID', 'Region_BUID', 'Region_UserID',
#        'Region_UserName', 'RegionName', 'Region_ReportingBUId', 'Div_BUID',
#        'Div_UserID', 'Div_UserName', 'DivName'],
#       dtype='object')

# %%
bmdf_today = today_df.groupby('BM_UserID').agg({
    'BM_UserName' : 'first',
    'Pending_Count' : 'sum',
    'collection_count' : 'sum',
    'proposal_count' : 'sum',
    'retention_count' : 'sum',
    'wrong_number_count' : 'sum',
}).reset_index().rename(columns={'BM_UserID': 'UserID','BM_UserName': 'UserName' })

# %%
bmdf_today
# Out:
#      UserID               UserName CallingNumber  Pending_Count  \
# 0        16            Manoj Kumar    9336367580              5
# 1        21             MOHD IRFAN    9696344756              2
# 2       109           SANJAY VERMA    9889109697              9
# 3       118  Jaswant Singh Chouhan    9752717355              1
# 4       229         LOKENDRA SINGH    9837253806              1
# ..      ...                    ...           ...            ...
# 261   27156              RAJ KUMAR    9151015726              1
# 262   27395    Digvijay Rahangdale    7067245928              7
# 263   27586           Rakesh Kumar    9931828563              3
# 264   27680           Ram Uday ray    9939802606              1
# 265   28105       Amit Kumar Singh    8799484661              1
#
#      collection_count  proposal_count  retention_count  wrong_number_count
# 0                   1               0                4                   0
# 1                   2               0                0                   0
# 2                   9               0                0                   0
# 3                   1               0                0                   0
# 4                   1               0                0                   0
# ..                ...             ...              ...                 ...
# 261                 0               0                1                   0
# 262                 3               0                1                   3
# 263                 0               0                0                   3
# 264                 1               0                0                   0
# 265                 0               0                0                   1
#
# [266 rows x 8 columns]

# %%
hubdf_today = today_df.groupby('Hub_UserID').agg({
    'Hub_UserName' : 'first',
    'Pending_Count' : 'sum',
    'collection_count' : 'sum',
    'proposal_count' : 'sum',
    'retention_count' : 'sum',
    'wrong_number_count' : 'sum',
}).reset_index().rename(columns={'Hub_UserID': 'UserID','Hub_UserName': 'UserName' })

# %%
hubdf_today
# Out:
#     UserID             UserName CallingNumber  Pending_Count  \
# 0        0  HUB HEAD NOT POSTED    8877781885             64
# 1      119       Shrikant Patel    6260693608             13
# 2      127      Rang Nath Yadav    9621450391              1
# 3      214          Vimal Singh    8400333298              3
# 4      215             YASH PAL    9889109697             14
# ..     ...                  ...           ...            ...
# 92   24795   Saurabh Srivastava    7080200377             12
# 93   24807              Mahipal    9368810178              2
# 94   24849         RITESH KUMAR    9336367580             13
# 95   24860        Santosh Kumar    8090954909             34
# 96   24867    Anil Kumar Maurya    8429524631              4
#
#     collection_count  proposal_count  retention_count  wrong_number_count
# 0                 40               0               19                   5
# 1                 13               0                0                   0
# 2                  0               0                0                   1
# 3                  0               0                2                   1
# 4                 14               0                0                   0
# ..               ...             ...              ...                 ...
# 92                 7               0                5                   0
# 93                 0               0                2                   0
# 94                 7               0                6                   0
# 95                32               0                2                   0
# 96                 2               0                2                   0
#
# [97 rows x 8 columns]

# %%
regdf_today = today_df.groupby('Region_UserID').agg({
    'Region_UserName' : 'first',
    'Pending_Count' : 'sum',
    'collection_count' : 'sum',
    'proposal_count' : 'sum',
    'retention_count' : 'sum',
    'wrong_number_count' : 'sum',
}).reset_index().rename(columns={'Region_UserID': 'UserID','Region_UserName': 'UserName' })

# %%
main_df[main_df['UserID'] == 1174]
# Out:
# Empty DataFrame
# Columns: [UserID, UserName, CallingNumber, Pending_Count, collection_count, proposal_count, retention_count, assigned_to, wrong_number_count]
# Index: []

# %%
regdf_today
# Out:
#     UserID                UserName  Pending_Count  collection_count  \
# 0        0  REGION HEAD NOT POSTED            181               163
# 1     1174           shama parveen             17                17
# 2     1622          Pradeep kachhi             11                 7
# 3     1968                  sompal             13                13
# 4     4347            SHIV BAHADUR             45                19
# 5     4708        DIPENDRA CHAUHAN             98                95
# 6     4891           Praveen Singh             55                50
# 7     7074                 Sudheer              1                 1
# 8     7114       Akash Jyoti singh             48                23
# 9     7342           Neeraj maurya             21                13
# 10    7664            Vikash Singh             18                18
# 11   10848     SHYAM KISHOR MISHRA             16                12
# 12   10850        Parasnath maorya            140               119
# 13   14050       ASHOK KUMAR YADAV             17                17
# 14   15054            RAKESH SINGH             27                 1
# 15   16347     Susheel Kumar Yadav             41                37
# 16   17692    ABHINAY KUMAR  DUBEY             50                43
# 17   17841           MURARI MAURYA              4                 0
# 18   18023            Vinayak Maha             30                30
# 19   18024       Shailendra Rajput             12                 7
# 20   18033         CHANDRA SHEKHAR              6                 3
# 21   18034      GRIJESH  CHAUDHARY             26                24
# 22   18035             MANOJ KUMAR             31                23
# 23   18036         SUBHASH CHANDRA             34                 2
# 24   18043              SHYAMANAND              2                 1
# 25   18044           KAMLESH YADAV             26                12
# 26   21479             Manoj Kumar             10                 7
# 27   23657      Suresh Kumar Saroj              8                 3
# 28   24776         RAJNAND  MAURYA             28                28
# 29   24808        BHOOPENDRA  SAHU             19                11
#
#     proposal_count  retention_count  wrong_number_count
# 0                0               15                   3
# 1                0                0                   0
# 2                0                2                   2
# 3                0                0                   0
# 4                0               26                   0
# 5                0                2                   1
# 6                0                0                   5
# 7                0                0                   0
# 8                0               25                   0
# 9                0                2                   6
# 10               0                0                   0
# 11               0                4                   0
# 12               0               17                   4
# 13               0                0                   0
# 14               0               26                   0
# 15               0                0                   4
# 16               0                1                   6
# 17               0                0                   4
# 18               0                0                   0
# 19               0                5                   0
# 20               0                0                   3
# 21               0                2                   0
# 22               0                4                   4
# 23               0                0                  32
# 24               0                0                   1
# 25               0               12                   2
# 26               0                0                   3
# 27               0                2                   3
# 28               0                0                   0
# 29               0                8                   0

# %%
divdf_today = today_df.groupby('Div_UserID').agg({
    'Div_UserName' : 'first',
    'Pending_Count' : 'sum',
    'collection_count' : 'sum',
    'proposal_count' : 'sum',
    'retention_count' : 'sum',
    'wrong_number_count' : 'sum',
}).reset_index().rename(columns={'Div_UserID': 'UserID','Div_UserName': 'UserName' })

# %%
divdf_today
# Out:
#     UserID                UserName  Pending_Count  collection_count  \
# 0     7535  RAKESH KUMAR CHAUDHARY            129               125
# 1     7575         CHANDRA SHEKHAR             48                14
# 2     7662           Sandeep Singh             48                48
# 3     9739          LAKSHMAN SINGH            119                54
# 4    10846    SHASHI BHUSHAN SINGH            125               120
# 5    10849           KESHRAJ YADAV            215               182
# 6    10851             Vinod singh             53                44
# 7    15111        Ajay Kumar Singh             97                55
# 8    15190          JITENDRA YADAV            127               108
# 9    17756              Alok Singh             70                49
# 10   22544        Shiv Kumar Singh              4                 0
#
#     proposal_count  retention_count  wrong_number_count
# 0                0                0                   4
# 1                0               28                   6
# 2                0                0                   0
# 3                0               63                   2
# 4                0                4                   1
# 5                0               25                   8
# 6                0                5                   4
# 7                0                2                  40
# 8                0               11                   8
# 9                0               15                   6
# 10               0                0                   4

# %%
final_df = pd.concat([main_df, bmdf_today, hubdf_today, divdf_today, regdf_today], axis=0).drop(columns=['assigned_to'])

# %%
final_df
# Out:
#     UserID            UserName CallingNumber  Pending_Count  collection_count  \
# 0     1478            Ram Roop    9076605730              1                 0
# 1     1709               Ballu    8960154523              2                 0
# 2     2107       Chiraunji Lal    7318080248              1                 0
# 3     2916        Vijay  Kumar    7080200377              1                 0
# 4     3004           Ram Jivan    7897996910             19                19
# ..     ...                 ...           ...            ...               ...
# 25   18044       KAMLESH YADAV    6394816074             26                12
# 26   21479         Manoj Kumar    8881697448             10                 7
# 27   23657  Suresh Kumar Saroj    8877781885              8                 3
# 28   24776     RAJNAND  MAURYA    6203641205             28                28
# 29   24808    BHOOPENDRA  SAHU    7821087963             19                11
#
#     proposal_count  retention_count  wrong_number_count
# 0                0                1                   0
# 1                0                2                   0
# 2                0                1                   0
# 3                0                1                   0
# 4                0                0                   0
# ..             ...              ...                 ...
# 25               0               12                   2
# 26               0                0                   3
# 27               0                2                   3
# 28               0                0                   0
# 29               0                8                   0
#
# [871 rows x 8 columns]

# %%
main_df[(main_df['CallingNumber'] == '7080200377') | (main_df['CallingNumber'] == '9129645463')]
# Out:
#      UserID      UserName CallingNumber  Pending_Count  collection_count  \
# 3      2916  Vijay  Kumar    7080200377              1                 0
# 164   27840   Vijay Kumar    9129645463              2                 1
#
#      proposal_count  retention_count  assigned_to  wrong_number_count
# 3                 0                1          0.0                   0
# 164               0                1          0.0                   0

# %%
main_df[main_df['UserName'] == 'Vijay Kumar']
# Out:
#      UserID     UserName CallingNumber  Pending_Count  collection_count  \
# 164   27840  Vijay Kumar    9129645463              2                 1
#
#      proposal_count  retention_count  assigned_to  wrong_number_count
# 164               0                1          0.0                   0

# %%
final_df[final_df['CallingNumber'] == '9076605730']
# Out:
#     UserID                 UserName CallingNumber  Pending_Count  \
# 0     1478                 Ram Roop    9076605730              1
# 70    3387            Krishna Kumar    9076605730              4
# 74    7660  Dharmendra Pratap Singh    9076605730             14
# 3     9739           LAKSHMAN SINGH    9076605730            119
# 4     4347             SHIV BAHADUR    9076605730             45
#
#     collection_count  proposal_count  retention_count  wrong_number_count
# 0                  0               0                1                   0
# 70                 1               0                3                   0
# 74                 4               0               10                   0
# 3                 54               0               63                   2
# 4                 19               0               26                   0
